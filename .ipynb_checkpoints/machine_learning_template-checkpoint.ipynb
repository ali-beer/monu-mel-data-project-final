# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("data", "social_abs_merged.csv"))
sample_df = df.drop(columns = ["name", "SA2_name", "SA2_MAINCODE_2016", "code", "on_track", "vulnerable", 
                              "total", "vulnerable_percentage", "Female_parent_Total_Total"])
sample_df = sample_df.drop(["Unnamed: 0"], axis=1)

# %%
sample_df.head()
# Out:
#    Index of Relative Socio-economic Disadvantage_score  \
# 0                                               1045
# 1                                               1035
# 2                                                999
# 3                                                926
# 4                                               1066
#
#    Index of Economic Resources_score  Index of Education and Occupation_score  \
# 0                               1037                                   1022.0
# 1                                975                                   1088.0
# 2                                972                                   1010.0
# 3                                904                                    946.0
# 4                               1048                                   1065.0
#
#    Male_Lone_Parent_Employed_Worked_Full_Time  \
# 0                                           3
# 1                                           5
# ...

# %%
target = sample_df["at_risk"]

# %%
data = sample_df.drop("at_risk", axis=1)
feature_names = data.columns
data
# Out:
#      Index of Relative Socio-economic Disadvantage_score  \
# 0                                                 1045
# 1                                                 1035
# 2                                                  999
# 3                                                  926
# 4                                                 1066
# ..                                                 ...
# 422                                                995
# 423                                               1008
# 424                                               1020
# 425                                                986
# 426                                                986
#
#      Index of Economic Resources_score  \
# 0                                 1037
# 1                                  975
# 2                                  972
# 3                                  904
# 4                                 1048
# ..                                 ...
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200) # parameters of the model - change estimators to see if you can get a better outcome

# %%
rf = rf.fit(X_train, y_train)

# %%
# These are the predictor values
# y_test - values you already know
predict_values = rf.predict(X_test)
predict_values
# Out:
# array([ 8.42 , 14.   , 27.14 , 10.53 , 89.085, 15.58 , 26.185, 16.875,
#        13.87 , 25.44 , 33.205, 31.055,  9.64 ,  7.55 , 27.24 , 25.125,
#        53.59 ,  6.59 , 10.21 ,  5.49 , 21.475, 54.245, 13.08 , 26.48 ,
#        22.215, 19.075, 23.68 ,  9.765, 14.355, 40.255, 11.285, 24.54 ,
#        17.   ,  9.665,  2.725, 25.26 , 18.41 , 10.975, 25.57 , 11.205,
#        31.945, 12.26 , 13.585, 31.02 , 14.28 , 14.07 ,  9.18 , 27.76 ,
#        10.67 ,  6.325, 10.675,  7.72 , 27.32 , 18.23 , 18.03 , 23.835,
#        65.24 , 10.92 , 24.92 , 16.49 , 13.1  , 32.525,  8.115,  6.57 ,
#        71.365, 11.95 , 10.025, 24.56 , 23.695, 32.55 , 46.09 , 14.865,
#        11.655, 24.47 , 31.61 , 11.735, 13.085, 32.365, 26.545, 17.725,
#        18.49 , 33.025,  5.755, 28.65 , 34.415, 29.84 ])

# %%
# Mean squared error example for project
# How far from the regression line the data points are
# Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors). 
# Residuals are a measure of how far from the regression line data points are; RMSE is a measure of how spread out these residuals are. 
# In other words, it tells you how concentrated the data is around the line of best fit.
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_test, predict_values)

from math import sqrt
rms = sqrt(mean_squared_error(y_test, predict_values))
rms
# will be an error of 0.5, the lower the error the better
# Out:
# 6.522028459962294

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.5837476370986124,
#   'Female_parent_Not_in_the_labour_force_Male_parent_Employed_Total'),
#  (0.10250493540300669, 'Total_Lone_Parents_Total_Employed'),
#  (0.04559214219388339, 'Female_Lone_Parent_Total'),
#  (0.03912485645970315, 'Total_Lone_Parents_Total'),
#  (0.0371856627612779, 'Female_Lone_Parent_Total_Employed'),
#  (0.02261139720692624,
#   'Female_parent_Total_Unemployed_Male_Parent_Employed_Total'),
#  (0.015064944667621608, 'Male_Lone_Parent_Total_Employed'),
#  (0.012469657824030176,
#   'Female_parent_Employed_worked_Full_time_Male_parent_Not_in_the_labour_force'),
#  (0.010731369556722384,
#   'Female_parent_Total_Employed_Male_Parent_Employed_Total'),
#  (0.010640638142350967,
#   'Female_parent_Employed_worked_Part_time_Male_parent_Employed_Worked_part_time'),
#  (0.010084899248707185,
#   'Female_parent_Employed_worked_Part_time_Male_parent_Employed_Total'),
#  (0.009651521658265622,
# ...
