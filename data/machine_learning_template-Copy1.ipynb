# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("data", "language_abs_merged2.csv"))

list(df.columns)
# Out:
# ['Unnamed: 0',
#  'SA2_MAINCODE_2016',
#  'D_0_4_FPEFT_MPEFT',
#  'D_0_4_FPEFT_MPEPT',
#  'D_0_4_FPEFT_MPEAW',
#  'D_0_4_FPEFT_MPEHNS',
#  'D_0_4_FPEFT_MPET',
#  'D_0_4_FPEFT_MPULFTW',
#  'D_0_4_FPEFT_MPULPTW',
#  'D_0_4_FPEFT_MPUT',
#  'D_0_4_FPEFT_MPTLF',
#  'D_0_4_FPEFT_MPNLF',
#  'D_0_4_FPEFT_MPLFSNS',
#  'D_0_4_FPEFT_T',
#  'D_0_4_FPEPT_MPEFT',
#  'D_0_4_FPEPT_MPEPT',
#  'D_0_4_FPEPT_MPEAW',
#  'D_0_4_FPEPT_MPEHNS',
#  'D_0_4_FPEPT_MPET',
#  'D_0_4_FPEPT_MPULFTW',
#  'D_0_4_FPEPT_MPULPTW',
#  'D_0_4_FPEPT_MPUT',
#  'D_0_4_FPEPT_MPTLF',
#  'D_0_4_FPEPT_MPNLF',
#  'D_0_4_FPEPT_MPLFSNS',
#  'D_0_4_FPEPT_T',
#  'D_0_4_FPEAW_MPEFT',
#  'D_0_4_FPEAW_MPEPT',
#  'D_0_4_FPEAW_MPEAW',
#  'D_0_4_FPEAW_MPEHNS',
#  'D_0_4_FPEAW_MPET',
#  'D_0_4_FPEAW_MPULFTW',
#  'D_0_4_FPEAW_MPULPTW',
#  'D_0_4_FPEAW_MPUT',
#  'D_0_4_FPEAW_MPTLF',
#  'D_0_4_FPEAW_MPNLF',
#  'D_0_4_FPEAW_MPLFSNS',
#  'D_0_4_FPEAW_T',
#  'D_0_4_FPHNS_MPEFT',
#  'D_0_4_FPHNS_MPEPT',
#  'D_0_4_FPHNS_MPEAW',
#  'D_0_4_FPHNS_MPEHNS',
#  'D_0_4_FPHNS_MPET',
#  'D_0_4_FPHNS_MPULFTW',
#  'D_0_4_FPHNS_MPULPTW',
#  'D_0_4_FPHNS_MPUT',
#  'D_0_4_FPHNS_MPTLF',
#  'D_0_4_FPHNS_MPNLF',
#  'D_0_4_FPHNS_MPLFSNS',
#  'D_0_4_FPHNS_T',
#  'D_0_4_FPET_MPEFT',
#  'D_0_4_FPET_MPEPT',
#  'D_0_4_FPET_MPEAW',
#  'D_0_4_FPET_MPEHNS',
#  'D_0_4_FPET_MPET',
#  'D_0_4_FPET_MPULFTW',
#  'D_0_4_FPET_MPULPTW',
#  'D_0_4_FPET_MPUT',
#  'D_0_4_FPET_MPTLF',
#  'D_0_4_FPET_MPNLF',
#  'D_0_4_FPET_MPLFSNS',
#  'D_0_4_FPET_T',
#  'D_0_4_FPULFTW_MPEFT',
#  'D_0_4_FPULFTW_MPEPT',
#  'D_0_4_FPULFTW_MP_EAW',
#  'D_0_4_FPULFTW_MP_E_HW_NS',
#  'D_0_4_FPULFTW_MPET',
#  'D_0_4_FPULFTW_MPULFTW',
#  'D_0_4_FPULFTW_MPULPTW',
#  'D_0_4_FPULFTW_MPUT',
#  'D_0_4_FPULFTW_MPTLF',
#  'D_0_4_FPULFTW_MPNLF',
#  'D_0_4_FPULFTW_MPLFSNS',
#  'D_0_4_FPULFTW_T',
#  'D_0_4_FPULPTW_MPEFT',
#  'D_0_4_FPULPTW_MPEPT',
#  'D_0_4_FPULPTW_MPEAW',
#  'D_0_4_FPULPTW_MPEm_HW_NS',
#  'D_0_4_FPULPTW_MPET',
#  'D_0_4_FPULPTW_MPULFTW',
#  'D_0_4_FPULPTW_MPULPTW',
#  'D_0_4_FPULPTW_MPUT',
#  'D_0_4_FPULPTW_MPTLF',
#  'D_0_4_FPULPTW_MPNLF',
#  'D_0_4_FPULPTW_MPLFSNS',
#  'D_0_4_FPULPTW_T',
#  'D_0_4_FPUT_MPEFT',
#  'D_0_4_FPUT_MPEPT',
#  'D_0_4_FPUT_MPEAW',
#  'D_0_4_FPUT_MP_E_HNS',
#  'D_0_4_FPUT_MPET',
#  'D_0_4_FPUT_MPULFTW',
#  'D_0_4_FPUT_MPULPTW',
#  'D_0_4_FPUT_MPUT',
#  'D_0_4_FPUT_MPTLF',
#  'D_0_4_FPUT_MPNLF',
#  'D_0_4_FPUT_MPLFSNS',
#  'D_0_4_FPUT_T',
#  'D_0_4_FPTLF_MPEFT',
#  'D_0_4_FPTLF_MPEPT',
#  'D_0_4_FPTLF_MPEAW',
#  'D_0_4_FPTLF_MPEHNS',
#  'D_0_4_FPTLF_MPET',
#  'D_0_4_FPTLF_MPULFTW',
#  'D_0_4_FPTLF_MPULPTW',
#  'D_0_4_FPTLF_MPUT',
#  'D_0_4_FPTLF_MPTLF',
#  'D_0_4_FPTLF_MPNLF',
#  'D_0_4_FPTLF_MPLFSNS',
#  'D_0_4_FPTLF_T',
#  'D_0_4_FPNLF_MPEFT',
#  'D_0_4_FPNLF_MPEPT',
#  'D_0_4_FPNLF_MPEAW',
#  'D_0_4_FPNLF_MP_E_HNS',
#  'D_0_4_FPNLF_MPET',
#  'D_0_4_FPNLF_MPUEmpLfFTW',
#  'D_0_4_FPNLF_MPUEmpLfPTW',
#  'D_0_4_FPNLF_MPUT',
#  'D_0_4_FPNLF_MPTLF',
#  'D_0_4_FPNLF_MPNLF',
#  'D_0_4_FPNLF_MPLFSNS',
#  'D_0_4_FPNLF_T',
#  'D_0_4_FPLFSNS_MPEFT',
#  'D_0_4_FPLFSNS_MPEPT',
#  'D_0_4_FPLFSNS_MPEAW',
#  'D_0_4_FPLFSNS_MP_E_HNS',
#  'D_0_4_FPLFSNS_MPET',
#  'D_0_4_FPLFSNS_MPULFTW',
#  'D_0_4_FPLFSNS_MPULPTW',
#  'D_0_4_FPLFSNS_MPUT',
#  'D_0_4_FPLFSNS_MPTLF',
#  'D_0_4_FPLFSNS_MPNLF',
#  'D_0_4_FPLFSNS_MPLFSNS',
#  'D_0_4_FPLFSNS_T',
#  'D_0_4_FPT_MPEFT',
#  'D_0_4_FPT_MPEPT',
#  'D_0_4_FPT_MPEAW',
#  'D_0_4_FPT_MPEHNS',
#  'D_0_4_FPT_MPET',
#  'D_0_4_FPT_MPULFTW',
#  'D_0_4_FPT_MPULPTW',
#  'D_0_4_FPT_MPUT',
#  'D_0_4_FPT_MPTLF',
#  'D_0_4_FPT_MPNLF',
#  'D_0_4_FPT_MPLFSNS',
#  'D_0_4_FPT_T',
#  'Male_Lone_Parent_Employed_Worked_Full_Time',
#  'Male_Lone_Parent_Employed_Worked_Part_Time',
#  'Male_Lone_Parent_Employed_Away_From_Work',
#  'Male_Lone_Parent_Hours_Worked_Not_Stated',
#  'Male_Lone_Parent_Total_Employed',
#  'Male_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Male_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Male_Lone_Parent_Total_Unemployed',
#  'Male_Lone_Parent_Total_Labour_Force',
#  'Male_Lone_Parent_Not_In_The_Labour_Force',
#  'Male_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Male_Lone_Parent_Total',
#  'Female_Lone_Parent_Employed_Worked_Full_Time',
#  'Female_Lone_Parent_Employed_Worked_Part_Time',
#  'Female_Lone_Parent_Employed_Away_From_Work',
#  'Female_Lone_Parent_Hours_Worked_Not_Stated',
#  'Female_Lone_Parent_Total_Employed',
#  'Female_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Female_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Female_Lone_Parent_Total_Unemployed',
#  'Female_Lone_Parent_Total_Labour_Force',
#  'Female_Lone_Parent_Not_In_The_Labour_Force',
#  'Female_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Female_Lone_Parent_Total',
#  'Total_Lone_Parents_Employed_Worked_Full_Time',
#  'Total_Lone_Parents_Employed_Worked_Part_Time',
#  'Total_Lone_Parents_Employed_Away_From_Work',
#  'Total_Lone_Parents_Hours_Worked_Not_Stated',
#  'Total_Lone_Parents_Total_Employed',
#  'Total_Lone_Parents_Unemployed_Looking_For_Full_Time_Work',
#  'Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work',
#  'Total_Lone_Parents_Total_Unemployed',
#  'Total_Lone_Parents_Total_Labour_Force',
#  'Total_Lone_Parents_Not_In_The_Labour_Force',
#  'Total_Lone_Parents_Labour_Force_Status_Not_Stated',
#  'Total_Lone_Parents_Total',
#  'SA2_name',
#  'Index of Relative Socio-economic Disadvantage_score',
#  'Index of Relative Socio-economic Disadvantage_decile',
#  'Index of Relative Socio-economic Adv and Disadv_score',
#  'Index of Relative Socio-economic Adv and Disadv_decile',
#  'Index of Economic Resources_score',
#  'Index of Economic Resources_decile',
#  'Index of Education and Occupation_score',
#  'Index of Education and Occupation_decile',
#  'Usual Resident Population',
#  'code',
#  'name',
#  'total',
#  'on_track',
#  'at_risk',
#  'vulnerable',
#  'vulnerable_percentage']

# %%
sample_df = df.drop(columns = ["Unnamed: 0", "SA2_MAINCODE_2016", "SA2_name", "Usual Resident Population", "code", "name", 
                              "total", "at_risk", "on_track", "vulnerable_percentage",
                              "Index of Relative Socio-economic Disadvantage_decile",
                              "Index of Relative Socio-economic Adv and Disadv_decile",
                              "Index of Economic Resources_decile",
                              "Index of Education and Occupation_decile"
                               ])

# %%
sample_df.head()
# Out:
#    D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 0                 64                 12                  0
# 1                 49                 10                  0
# 2                 86                 16                  0
# 3                 66                 15                  3
# 4                 30                  0                  0
#
#    D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 0                   3                74                    0
# 1                   0                59                    0
# 2                   0               107                    3
# 3                   0                88                    4
# 4                   0                34                    0
#
#    D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 0                    0                 0                 78
# 1                    0                 0                 59
# 2                    0                 3                104
# 3                    3                 5                 92
# 4                    0                 0                 32
#
#    D_0_4_FPEFT_MPNLF  ...  Total_Lone_Parents_Total_Unemployed  \
# 0                  3  ...                                    3
# 1                  0  ...                                    9
# 2                  9  ...                                   18
# 3                 10  ...                                   22
# 4                  3  ...                                    0
#
#    Total_Lone_Parents_Total_Labour_Force  \
# 0                                     34
# 1                                     39
# 2                                     87
# 3                                    126
# 4                                      9
#
#    Total_Lone_Parents_Not_In_The_Labour_Force  \
# 0                                          47
# 1                                          35
# 2                                         110
# 3                                         261
# 4                                          17
#
#    Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  5
# 4                                                  0
#
#    Total_Lone_Parents_Total  \
# 0                        82
# 1                        77
# 2                       198
# 3                       388
# 4                        29
#
#    Index of Relative Socio-economic Disadvantage_score  \
# 0                                               1045
# 1                                               1035
# 2                                                999
# 3                                                926
# 4                                               1066
#
#    Index of Relative Socio-economic Adv and Disadv_score  \
# 0                                               1025
# 1                                               1037
# 2                                                983
# 3                                                912
# 4                                               1051
#
#    Index of Economic Resources_score  Index of Education and Occupation_score  \
# 0                               1037                                   1022.0
# 1                                975                                   1088.0
# 2                                972                                   1010.0
# 3                                904                                    946.0
# 4                               1048                                   1065.0
#
#    vulnerable
# 0           6
# 1           3
# 2          18
# 3          17
# 4           3
#
# [5 rows x 185 columns]

# %%
target = sample_df["vulnerable"]

# %%
data = sample_df.drop("vulnerable", axis=1)
feature_names = data.columns
data
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 0                   64                 12                  0
# 1                   49                 10                  0
# 2                   86                 16                  0
# 3                   66                 15                  3
# 4                   30                  0                  0
# ..                 ...                ...                ...
# 422                  9                  0                  0
# 423                 35                  3                  0
# 424                 39                  3                  0
# 425                 67                 12                  0
# 426                 33                 10                  0
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 0                     3                74                    0
# 1                     0                59                    0
# 2                     0               107                    3
# 3                     0                88                    4
# 4                     0                34                    0
# ..                  ...               ...                  ...
# 422                   0                10                    0
# 423                   0                39                    0
# 424                   3                45                    0
# 425                   0                84                    3
# 426                   0                46                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 0                      0                 0                 78
# 1                      0                 0                 59
# 2                      0                 3                104
# 3                      3                 5                 92
# 4                      0                 0                 32
# ..                   ...               ...                ...
# 422                    0                 0                 10
# 423                    0                 0                 39
# 424                    0                 0                 45
# 425                    0                 3                 89
# 426                    0                 0                 46
#
#      D_0_4_FPEFT_MPNLF  ...  \
# 0                    3  ...
# 1                    0  ...
# 2                    9  ...
# 3                   10  ...
# 4                    3  ...
# ..                 ...  ...
# 422                  0  ...
# 423                  3  ...
# 424                  3  ...
# 425                 16  ...
# 426                  5  ...
#
#      Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work  \
# 0                                                    3
# 1                                                    0
# 2                                                   12
# 3                                                   17
# 4                                                    0
# ..                                                 ...
# 422                                                  0
# 423                                                  0
# 424                                                  0
# 425                                                  3
# 426                                                  0
#
#      Total_Lone_Parents_Total_Unemployed  \
# 0                                      3
# 1                                      9
# 2                                     18
# 3                                     22
# 4                                      0
# ..                                   ...
# 422                                    0
# 423                                    0
# 424                                    0
# 425                                    6
# 426                                    0
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 0                                       34
# 1                                       39
# 2                                       87
# 3                                      126
# 4                                        9
# ..                                     ...
# 422                                     12
# 423                                     19
# 424                                     24
# 425                                     80
# 426                                     41
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 0                                            47
# 1                                            35
# 2                                           110
# 3                                           261
# 4                                            17
# ..                                          ...
# 422                                           3
# 423                                          14
# 424                                          27
# 425                                         131
# 426                                          68
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    5
# 4                                                    0
# ..                                                 ...
# 422                                                  0
# 423                                                  0
# 424                                                  0
# 425                                                  7
# 426                                                  3
#
#      Total_Lone_Parents_Total  \
# 0                          82
# 1                          77
# 2                         198
# 3                         388
# 4                          29
# ..                        ...
# 422                        14
# 423                        34
# 424                        50
# 425                       217
# 426                       112
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 0                                                 1045
# 1                                                 1035
# 2                                                  999
# 3                                                  926
# 4                                                 1066
# ..                                                 ...
# 422                                                995
# 423                                               1008
# 424                                               1020
# 425                                                986
# 426                                                986
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 0                                                 1025
# 1                                                 1037
# 2                                                  983
# 3                                                  912
# 4                                                 1051
# ..                                                 ...
# 422                                                976
# 423                                                995
# 424                                                998
# 425                                                958
# 426                                                966
#
#      Index of Economic Resources_score  \
# 0                                 1037
# 1                                  975
# 2                                  972
# 3                                  904
# 4                                 1048
# ..                                 ...
# 422                                988
# 423                               1037
# 424                               1026
# 425                                976
# 426                                961
#
#      Index of Education and Occupation_score
# 0                                     1022.0
# 1                                     1088.0
# 2                                     1010.0
# 3                                      946.0
# 4                                     1065.0
# ..                                       ...
# 422                                   1010.0
# 423                                   1003.0
# 424                                   1009.0
# 425                                    952.0
# 426                                    981.0
#
# [427 rows x 184 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100) # parameters of the model - change estimators to see if you can get a better outcome

# %%
rf = rf.fit(X_train, y_train)

# %%
# These are the predictor values
# y_test - values you already know
predict_values = rf.predict(X_test)
predict_values
# Out:
# array([ 2.36,  6.63, 18.19,  2.32, 48.63,  5.54,  6.85,  3.51,  3.06,
#        10.35, 21.18, 16.51,  3.67,  2.64, 11.8 ,  6.61, 18.33,  1.84,
#         5.02,  2.45,  9.75, 28.84,  7.03, 12.99,  4.9 ,  6.65,  6.65,
#         3.71,  6.63, 17.25,  3.55, 14.82,  6.55,  2.79,  2.58, 17.94,
#         9.73,  3.8 ,  6.88,  4.47, 28.83,  1.99,  8.83, 18.25,  4.4 ,
#         3.88,  3.9 , 15.57,  5.24,  1.64, 11.44,  3.33, 11.43,  8.39,
#        10.35,  5.46, 30.52,  5.02,  4.95,  8.03,  3.14, 12.24,  3.92,
#         2.47, 38.82,  4.46,  4.14,  7.32,  5.26, 12.57, 25.98, 10.92,
#         9.32,  7.14, 18.03,  4.09,  4.02, 15.91, 13.98,  4.32,  5.44,
#        14.97,  2.58, 17.1 , 15.37, 21.16])

# %%
# Now, we fit our StandardScaler model to our training data. We can apply this StandardScaler model to any future data. Note that we use this fit/transform approach so that we isolate our testing data from the training data that we use to fit our model. Otherwise, we might bias our model to the testing data.
# If working with different units of measurement - allows us to 
# standardised the scaling - reduces the magnitude of numbers while still maintaining the
# truth of the relative distance between our numerical observations
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# when you express different attributes on different scales of magnitude - for the scales
# that result in bigger numbers - your machine learning algorithm may hon in
# on those bigger values because there is more variety within that column - to remove
# that biasing effect of these large numbers we rescale our values - reduce the amount of 
# variety in that column between the largest value and the smallest value.
# reducing the magnitude of the variance within our data.

# %%
# general standard when building a model is to apply some scaling. (mm and kg - rescale mm to m)
# Create versions of our x and y data that have been rescaled
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test) # apply same trasformation/scaling to our test data
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["size"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["size"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %%
plt.show()
# scaled data - same shape just reduced the space that our values fall into - more compact
# rescaling the data - still preserves the underlying truth of the data
# relative positioning of our data remains true

# %%
# Mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, predict_values)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-b000ced31ef2> in <module>
#       1 # Mean absolute percentage error
#       2
# ----> 3 from sklearn.metrics import mean_absolute_percentage_error
#       4
#       5 mean_absolute_percentage_error(y_test, predict_values)
#
# ImportError: cannot import name 'mean_absolute_percentage_error' from 'sklearn.metrics' (C:\Users\beera\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\__init__.py)

# %%
MAPE = (1/n) * Σ(|actual – forecast| / |actual|) * 100

# %%
# Mean squared error example for project
# How far from the regression line the data points are
# Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors). 
# Residuals are a measure of how far from the regression line data points are; RMSE is a measure of how spread out these residuals are. 
# In other words, it tells you how concentrated the data is around the line of best fit.
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, predict_values)

from math import sqrt
rms = sqrt(mean_squared_error(y_test, predict_values))
rms
# will be an error of 0.5, the lower the error the better
# Out:
# 4.271132005060387

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.24457110551037953, 'Total_Lone_Parents_Total'),
#  (0.12624721213349727, 'Female_Lone_Parent_Total'),
#  (0.08946639087894698, 'Female_Lone_Parent_Not_In_The_Labour_Force'),
#  (0.06031401677800871, 'D_0_4_FPNLF_T'),
#  (0.046651445695584465, 'Total_Lone_Parents_Not_In_The_Labour_Force'),
#  (0.03832029074877612, 'D_0_4_FPT_MPNLF'),
#  (0.028409152655095714, 'D_0_4_FPNLF_MPEPT'),
#  (0.02779942036853127, 'D_0_4_FPT_MPULFTW'),
#  (0.025278453762084294, 'D_0_4_FPT_MPUT'),
#  (0.0178763449772232, 'Total_Lone_Parents_Total_Unemployed'),
#  (0.015058268143870028, 'D_0_4_FPT_MPEPT'),
#  (0.01172087360027553, 'D_0_4_FPNLF_MPNLF'),
#  (0.010781538718810935, 'D_0_4_FPNLF_MPTLF'),
#  (0.009756644123380197, 'D_0_4_FPULFTW_MPTLF'),
#  (0.009718239059510546, 'Total_Lone_Parents_Total_Labour_Force'),
#  (0.008959581782690792, 'D_0_4_FPNLF_MPUT'),
#  (0.0077099296727171215,
#   'Female_Lone_Parent_Unemployed_Looking_For_Part_Time_Work'),
#  (0.0077044232796038715, 'Female_Lone_Parent_Total_Labour_Force'),
#  (0.0068540036991908415, 'D_0_4_FPULFTW_MPEFT'),
#  (0.006541023491183282, 'D_0_4_FPEPT_MPNLF'),
#  (0.005920103398044703, 'D_0_4_FPNLF_MPLFSNS'),
#  (0.005696097660212839, 'Female_Lone_Parent_Labour_Force_Status_Not_Stated'),
#  (0.005305560995493013, 'Male_Lone_Parent_Total'),
#  (0.005173067215574385, 'D_0_4_FPET_MPULFTW'),
#  (0.0050728226583398005, 'D_0_4_FPT_MPULPTW'),
#  (0.005021047606209032, 'D_0_4_FPEPT_MPUT'),
#  (0.004841388411062552, 'D_0_4_FPTLF_MPNLF'),
#  (0.004087366423791461, 'D_0_4_FPULFTW_T'),
#  (0.00346808197922103, 'Male_Lone_Parent_Total_Labour_Force'),
#  (0.0033839592639167537, 'D_0_4_FPUT_MPET'),
#  (0.0033565719603036327, 'D_0_4_FPEFT_MPEPT'),
#  (0.0033350245580807546, 'Index of Education and Occupation_decile'),
#  (0.0032295335356453715, 'D_0_4_FPNLF_MPUEmpLfFTW'),
#  (0.0031056892149653494, 'Male_Lone_Parent_Not_In_The_Labour_Force'),
#  (0.003077166893768328, 'D_0_4_FPNLF_MPEAW'),
#  (0.0030112974221062514, 'D_0_4_FPNLF_MPET'),
#  (0.0029523032388487935, 'D_0_4_FPT_MPEAW'),
#  (0.0029388069848078863, 'D_0_4_FPULPTW_MPTLF'),
#  (0.002842012075226685, 'D_0_4_FPEFT_MPNLF'),
#  (0.0027660319480308695, 'D_0_4_FPTLF_MPEPT'),
#  (0.0025850965049359596, 'D_0_4_FPT_MPLFSNS'),
#  (0.002499347712150799, 'D_0_4_FPT_MPEHNS'),
#  (0.0024776835705411005, 'D_0_4_FPNLF_MPEFT'),
#  (0.002347321900009783, 'D_0_4_FPEPT_MPEAW'),
#  (0.002346351425094898, 'D_0_4_FPTLF_MPULFTW'),
#  (0.002326168339950357,
#   'Total_Lone_Parents_Unemployed_Looking_For_Full_Time_Work'),
#  (0.0022550235228199224, 'D_0_4_FPEPT_MPEHNS'),
#  (0.002242410688090839, 'D_0_4_FPT_MPET'),
#  (0.0022334020440932683, 'D_0_4_FPULFTW_MPET'),
#  (0.002113175377121374, 'D_0_4_FPUT_MPEFT'),
#  (0.00204986261445189, 'Female_Lone_Parent_Employed_Worked_Part_Time'),
#  (0.0020480373734176206, 'Male_Lone_Parent_Total_Employed'),
#  (0.0020119111674365892, 'Total_Lone_Parents_Employed_Worked_Part_Time'),
#  (0.001977109088582517, 'D_0_4_FPNLF_MP_E_HNS'),
#  (0.001864303948526742, 'D_0_4_FPET_MPUT'),
#  (0.0018388878758294374, 'D_0_4_FPUT_MPEPT'),
#  (0.0017771858177134023, 'D_0_4_FPHNS_MPEFT'),
#  (0.0017581855281178789, 'Total_Lone_Parents_Employed_Worked_Full_Time'),
#  (0.0017340298845671775, 'D_0_4_FPEAW_MPEPT'),
#  (0.0017171160606464528, 'D_0_4_FPET_MPEHNS'),
#  (0.0016590292984081734, 'D_0_4_FPEAW_MPEAW'),
#  (0.0016583470746264466, 'D_0_4_FPTLF_MPEAW'),
#  (0.0016445312316441007, 'Female_Lone_Parent_Employed_Worked_Full_Time'),
#  (0.0016164356535706076,
#   'Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work'),
#  (0.0016050406204379964, 'Total_Lone_Parents_Labour_Force_Status_Not_Stated'),
#  (0.001560928044972372, 'D_0_4_FPEPT_MPULFTW'),
#  (0.0015413121358483473, 'D_0_4_FPTLF_MPUT'),
#  (0.0015228477280999039, 'D_0_4_FPLFSNS_T'),
#  (0.0015126557201615137, 'D_0_4_FPUT_T'),
#  (0.0015049434189563517, 'Female_Lone_Parent_Total_Unemployed'),
#  (0.0015046176061322162, 'Female_Lone_Parent_Total_Employed'),
#  (0.0014221355474052025, 'D_0_4_FPTLF_MPEHNS'),
#  (0.0013836343950635005, 'D_0_4_FPET_MPNLF'),
#  (0.001334685577337326, 'D_0_4_FPEPT_MPEPT'),
#  (0.001332285979380666, 'D_0_4_FPEFT_MPEHNS'),
#  (0.0013032437502780209, 'D_0_4_FPULPTW_MPULFTW'),
#  (0.0012507465939804244, 'D_0_4_FPUT_MPULPTW'),
#  (0.0012425044608106806, 'D_0_4_FPET_MPEAW'),
#  (0.0012215057430885884, 'D_0_4_FPHNS_T'),
#  (0.0011759225345369152, 'Total_Lone_Parents_Employed_Away_From_Work'),
#  (0.0011730390353678099, 'D_0_4_FPUT_MPTLF'),
#  (0.0011685563171544221, 'Total_Lone_Parents_Total_Employed'),
#  (0.0011614926379931066, 'Female_Lone_Parent_Hours_Worked_Not_Stated'),
#  (0.001154635296456637, 'D_0_4_FPEFT_MPTLF'),
#  (0.0011395028546437676, 'D_0_4_FPULPTW_MPET'),
#  (0.0011317304064076166, 'D_0_4_FPT_MPTLF'),
#  (0.0010954205818752836, 'D_0_4_FPULFTW_MPUT'),
#  (0.0010752630151153054, 'Index of Economic Resources_decile'),
#  (0.0010733123443803546, 'D_0_4_FPULPTW_MPEPT'),
#  (0.0010730987547558435, 'D_0_4_FPLFSNS_MPNLF'),
#  (0.0010545635875832352, 'D_0_4_FPET_MPEPT'),
#  (0.0010391341287759575, 'D_0_4_FPULFTW_MPEPT'),
#  (0.0010020240127698178, 'Female_Lone_Parent_Employed_Away_From_Work'),
#  (0.0009890365953244037, 'Male_Lone_Parent_Total_Unemployed'),
#  (0.0009717743131628365, 'D_0_4_FPEFT_MPULFTW'),
#  (0.0009572486099068093, 'D_0_4_FPEAW_MPET'),
#  (0.0009454607181784923,
#   'Index of Relative Socio-economic Adv and Disadv_decile'),
#  (0.0009433321178280528, 'D_0_4_FPEFT_MPUT'),
#  (0.0009395185085456999, 'D_0_4_FPHNS_MPEHNS'),
#  (0.0009384448576540953, 'D_0_4_FPNLF_MPUEmpLfPTW'),
#  (0.0009374889637226194,
#   'Index of Relative Socio-economic Disadvantage_decile'),
#  (0.0009333582191650936, 'D_0_4_FPULPTW_MPEFT'),
#  (0.0009233946715996129, 'D_0_4_FPLFSNS_MPTLF'),
#  (0.0009198098604955403, 'D_0_4_FPEAW_MPEFT'),
#  (0.0008879624796389775, 'Male_Lone_Parent_Employed_Worked_Full_Time'),
#  (0.0008810668897959573, 'D_0_4_FPEAW_T'),
#  (0.0008656598870718028, 'D_0_4_FPEFT_MPEFT'),
#  (0.0008607978031043301, 'D_0_4_FPHNS_MPTLF'),
#  (0.0008332020966312318, 'D_0_4_FPHNS_MPET'),
#  (0.0008326122311814986, 'D_0_4_FPEAW_MPTLF'),
#  (0.0007967387118667603, 'D_0_4_FPEFT_T'),
#  (0.0007871306006170579, 'D_0_4_FPEPT_MPET'),
#  (0.0007759634376979177, 'D_0_4_FPUT_MPUT'),
#  (0.0007352106716732401, 'D_0_4_FPULPTW_MPUT'),
#  (0.0007191963499224475, 'D_0_4_FPEAW_MPNLF'),
#  (0.0007039136820027147, 'D_0_4_FPT_MPEFT'),
#  (0.000700647660128684, 'D_0_4_FPEPT_MPEFT'),
#  (0.0006983908565749368, 'D_0_4_FPLFSNS_MP_E_HNS'),
#  (0.0006830806175436811, 'D_0_4_FPEFT_MPET'),
#  (0.0006490285739961456, 'D_0_4_FPET_MPULPTW'),
#  (0.0006426276430932589, 'D_0_4_FPULFTW_MPULFTW'),
#  (0.0006395275670271848, 'D_0_4_FPEFT_MPEAW'),
#  (0.0006119453902374226, 'D_0_4_FPEPT_MPTLF'),
#  (0.0005995959208452007, 'D_0_4_FPULPTW_T'),
#  (0.0005953879934509672, 'D_0_4_FPTLF_MPULPTW'),
#  (0.0005714005793993237, 'D_0_4_FPEAW_MPULFTW'),
#  (0.0005560589596711017, 'D_0_4_FPLFSNS_MPEFT'),
#  (0.0005553901171155185, 'D_0_4_FPTLF_MPEFT'),
#  (0.0005114928438883312, 'D_0_4_FPET_MPEFT'),
#  (0.0005002688235589134, 'D_0_4_FPUT_MPULFTW'),
#  (0.00047847578380100285, 'D_0_4_FPET_MPTLF'),
#  (0.00045984891378168265, 'D_0_4_FPT_T'),
#  (0.00042708775256744997, 'Total_Lone_Parents_Hours_Worked_Not_Stated'),
#  (0.0004198752540356641, 'D_0_4_FPUT_MPNLF'),
#  (0.00041795107015404995, 'D_0_4_FPHNS_MPEPT'),
#  (0.0004175889028234817, 'D_0_4_FPET_MPET'),
#  (0.0004117138335626554, 'D_0_4_FPEPT_T'),
#  (0.0003973380974158105, 'Male_Lone_Parent_Employed_Worked_Part_Time'),
#  (0.00038875384720062274, 'D_0_4_FPET_T'),
#  (0.00037951194235970683, 'D_0_4_FPLFSNS_MPLFSNS'),
#  (0.0003696320705441146, 'Male_Lone_Parent_Hours_Worked_Not_Stated'),
#  (0.00033547594223883986, 'D_0_4_FPTLF_MPET'),
#  (0.00029510210401934576,
#   'Female_Lone_Parent_Unemployed_Looking_For_Full_Time_Work'),
#  (0.0002797099402161611, 'D_0_4_FPTLF_T'),
#  (0.00020215101495516053, 'D_0_4_FPLFSNS_MPET'),
#  (0.00019117959775577636,
#   'Male_Lone_Parent_Unemployed_Looking_For_Part_Time_Work'),
#  (0.00018348156760376394, 'D_0_4_FPHNS_MPNLF'),
#  (0.0001579322791762607, 'D_0_4_FPULFTW_MPNLF'),
#  (0.00014999455706663265, 'D_0_4_FPEFT_MPULPTW'),
#  (0.00013750083818531833, 'D_0_4_FPEAW_MPEHNS'),
#  (0.00013198751544234573,
#   'Male_Lone_Parent_Unemployed_Looking_For_Full_Time_Work'),
#  (0.0001312842326352622, 'D_0_4_FPTLF_MPTLF'),
#  (0.0001007507419005779, 'D_0_4_FPTLF_MPLFSNS'),
#  (9.805613154238203e-05, 'D_0_4_FPEAW_MPUT'),
#  (9.656128461915547e-05, 'D_0_4_FPUT_MP_E_HNS'),
#  (8.304507899964124e-05, 'D_0_4_FPUT_MPEAW'),
#  (5.774185724106504e-05, 'D_0_4_FPULPTW_MPEAW'),
#  (5.329481329067795e-05, 'D_0_4_FPULPTW_MPULPTW'),
#  (4.371073039909032e-05, 'D_0_4_FPULPTW_MPLFSNS'),
#  (3.820715222021844e-05, 'D_0_4_FPEPT_MPULPTW'),
#  (3.675511851250565e-05, 'D_0_4_FPET_MPLFSNS'),
#  (3.363511526613963e-05, 'D_0_4_FPLFSNS_MPEPT'),
#  (3.064710841673306e-05, 'Male_Lone_Parent_Labour_Force_Status_Not_Stated'),
#  (3.023661846898235e-05, 'D_0_4_FPULPTW_MPNLF'),
#  (2.66510890361227e-05, 'D_0_4_FPULFTW_MP_E_HW_NS'),
#  (1.585262381075552e-05, 'D_0_4_FPULFTW_MPULPTW'),
#  (8.365005576051955e-06, 'D_0_4_FPHNS_MPUT'),
#  (8.327880783429098e-06, 'D_0_4_FPEAW_MPULPTW'),
#  (6.7226973598158396e-06, 'Male_Lone_Parent_Employed_Away_From_Work'),
#  (2.9727780451603603e-06, 'D_0_4_FPEPT_MPLFSNS'),
#  (2.7339411968307514e-06, 'D_0_4_FPHNS_MPULPTW'),
#  (1.5337440198072452e-06, 'D_0_4_FPLFSNS_MPEAW'),
#  (1.2574098937553575e-06, 'D_0_4_FPHNS_MPLFSNS'),
#  (6.611607524917317e-07, 'D_0_4_FPLFSNS_MPUT'),
#  (5.95201393853439e-07, 'D_0_4_FPULPTW_MPEm_HW_NS'),
#  (5.623444614290451e-07, 'D_0_4_FPHNS_MPULFTW'),
#  (3.5043680766250117e-07, 'D_0_4_FPHNS_MPEAW'),
#  (0.0, 'D_0_4_FPUT_MPLFSNS'),
#  (0.0, 'D_0_4_FPULFTW_MP_EAW'),
#  (0.0, 'D_0_4_FPULFTW_MPLFSNS'),
#  (0.0, 'D_0_4_FPLFSNS_MPULPTW'),
#  (0.0, 'D_0_4_FPLFSNS_MPULFTW'),
#  (0.0, 'D_0_4_FPEFT_MPLFSNS'),
#  (0.0, 'D_0_4_FPEAW_MPLFSNS')]
