# %%
from sklearn import tree
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.path.join("merged", "language_abs_merged.csv"))

list(df.columns)
# Out:
# ['Unnamed: 0',
#  'SA2_MAINCODE_2016',
#  'D_0_4_FPEFT_MPEFT',
#  'D_0_4_FPEFT_MPEPT',
#  'D_0_4_FPEFT_MPEAW',
#  'D_0_4_FPEFT_MPEHNS',
#  'D_0_4_FPEFT_MPET',
#  'D_0_4_FPEFT_MPULFTW',
#  'D_0_4_FPEFT_MPULPTW',
#  'D_0_4_FPEFT_MPUT',
#  'D_0_4_FPEFT_MPTLF',
#  'D_0_4_FPEFT_MPNLF',
#  'D_0_4_FPEFT_MPLFSNS',
#  'D_0_4_FPEFT_T',
#  'D_0_4_FPEPT_MPEFT',
#  'D_0_4_FPEPT_MPEPT',
#  'D_0_4_FPEPT_MPEAW',
#  'D_0_4_FPEPT_MPEHNS',
#  'D_0_4_FPEPT_MPET',
#  'D_0_4_FPEPT_MPULFTW',
#  'D_0_4_FPEPT_MPULPTW',
#  'D_0_4_FPEPT_MPUT',
#  'D_0_4_FPEPT_MPTLF',
#  'D_0_4_FPEPT_MPNLF',
#  'D_0_4_FPEPT_MPLFSNS',
#  'D_0_4_FPEPT_T',
#  'D_0_4_FPEAW_MPEFT',
#  'D_0_4_FPEAW_MPEPT',
#  'D_0_4_FPEAW_MPEAW',
#  'D_0_4_FPEAW_MPEHNS',
#  'D_0_4_FPEAW_MPET',
#  'D_0_4_FPEAW_MPULFTW',
#  'D_0_4_FPEAW_MPULPTW',
#  'D_0_4_FPEAW_MPUT',
#  'D_0_4_FPEAW_MPTLF',
#  'D_0_4_FPEAW_MPNLF',
#  'D_0_4_FPEAW_MPLFSNS',
#  'D_0_4_FPEAW_T',
#  'D_0_4_FPHNS_MPEFT',
#  'D_0_4_FPHNS_MPEPT',
#  'D_0_4_FPHNS_MPEAW',
#  'D_0_4_FPHNS_MPEHNS',
#  'D_0_4_FPHNS_MPET',
#  'D_0_4_FPHNS_MPULFTW',
#  'D_0_4_FPHNS_MPULPTW',
#  'D_0_4_FPHNS_MPUT',
#  'D_0_4_FPHNS_MPTLF',
#  'D_0_4_FPHNS_MPNLF',
#  'D_0_4_FPHNS_MPLFSNS',
#  'D_0_4_FPHNS_T',
#  'D_0_4_FPET_MPEFT',
#  'D_0_4_FPET_MPEPT',
#  'D_0_4_FPET_MPEAW',
#  'D_0_4_FPET_MPEHNS',
#  'D_0_4_FPET_MPET',
#  'D_0_4_FPET_MPULFTW',
#  'D_0_4_FPET_MPULPTW',
#  'D_0_4_FPET_MPUT',
#  'D_0_4_FPET_MPTLF',
#  'D_0_4_FPET_MPNLF',
#  'D_0_4_FPET_MPLFSNS',
#  'D_0_4_FPET_T',
#  'D_0_4_FPULFTW_MPEFT',
#  'D_0_4_FPULFTW_MPEPT',
#  'D_0_4_FPULFTW_MP_EAW',
#  'D_0_4_FPULFTW_MP_E_HW_NS',
#  'D_0_4_FPULFTW_MPET',
#  'D_0_4_FPULFTW_MPULFTW',
#  'D_0_4_FPULFTW_MPULPTW',
#  'D_0_4_FPULFTW_MPUT',
#  'D_0_4_FPULFTW_MPTLF',
#  'D_0_4_FPULFTW_MPNLF',
#  'D_0_4_FPULFTW_MPLFSNS',
#  'D_0_4_FPULFTW_T',
#  'D_0_4_FPULPTW_MPEFT',
#  'D_0_4_FPULPTW_MPEPT',
#  'D_0_4_FPULPTW_MPEAW',
#  'D_0_4_FPULPTW_MPEm_HW_NS',
#  'D_0_4_FPULPTW_MPET',
#  'D_0_4_FPULPTW_MPULFTW',
#  'D_0_4_FPULPTW_MPULPTW',
#  'D_0_4_FPULPTW_MPUT',
#  'D_0_4_FPULPTW_MPTLF',
#  'D_0_4_FPULPTW_MPNLF',
#  'D_0_4_FPULPTW_MPLFSNS',
#  'D_0_4_FPULPTW_T',
#  'D_0_4_FPUT_MPEFT',
#  'D_0_4_FPUT_MPEPT',
#  'D_0_4_FPUT_MPEAW',
#  'D_0_4_FPUT_MP_E_HNS',
#  'D_0_4_FPUT_MPET',
#  'D_0_4_FPUT_MPULFTW',
#  'D_0_4_FPUT_MPULPTW',
#  'D_0_4_FPUT_MPUT',
#  'D_0_4_FPUT_MPTLF',
#  'D_0_4_FPUT_MPNLF',
#  'D_0_4_FPUT_MPLFSNS',
#  'D_0_4_FPUT_T',
#  'D_0_4_FPTLF_MPEFT',
#  'D_0_4_FPTLF_MPEPT',
#  'D_0_4_FPTLF_MPEAW',
#  'D_0_4_FPTLF_MPEHNS',
#  'D_0_4_FPTLF_MPET',
#  'D_0_4_FPTLF_MPULFTW',
#  'D_0_4_FPTLF_MPULPTW',
#  'D_0_4_FPTLF_MPUT',
#  'D_0_4_FPTLF_MPTLF',
#  'D_0_4_FPTLF_MPNLF',
#  'D_0_4_FPTLF_MPLFSNS',
#  'D_0_4_FPTLF_T',
#  'D_0_4_FPNLF_MPEFT',
#  'D_0_4_FPNLF_MPEPT',
#  'D_0_4_FPNLF_MPEAW',
#  'D_0_4_FPNLF_MP_E_HNS',
#  'D_0_4_FPNLF_MPET',
#  'D_0_4_FPNLF_MPUEmpLfFTW',
#  'D_0_4_FPNLF_MPUEmpLfPTW',
#  'D_0_4_FPNLF_MPUT',
#  'D_0_4_FPNLF_MPTLF',
#  'D_0_4_FPNLF_MPNLF',
#  'D_0_4_FPNLF_MPLFSNS',
#  'D_0_4_FPNLF_T',
#  'D_0_4_FPLFSNS_MPEFT',
#  'D_0_4_FPLFSNS_MPEPT',
#  'D_0_4_FPLFSNS_MPEAW',
#  'D_0_4_FPLFSNS_MP_E_HNS',
#  'D_0_4_FPLFSNS_MPET',
#  'D_0_4_FPLFSNS_MPULFTW',
#  'D_0_4_FPLFSNS_MPULPTW',
#  'D_0_4_FPLFSNS_MPUT',
#  'D_0_4_FPLFSNS_MPTLF',
#  'D_0_4_FPLFSNS_MPNLF',
#  'D_0_4_FPLFSNS_MPLFSNS',
#  'D_0_4_FPLFSNS_T',
#  'D_0_4_FPT_MPEFT',
#  'D_0_4_FPT_MPEPT',
#  'D_0_4_FPT_MPEAW',
#  'D_0_4_FPT_MPEHNS',
#  'D_0_4_FPT_MPET',
#  'D_0_4_FPT_MPULFTW',
#  'D_0_4_FPT_MPULPTW',
#  'D_0_4_FPT_MPUT',
#  'D_0_4_FPT_MPTLF',
#  'D_0_4_FPT_MPNLF',
#  'D_0_4_FPT_MPLFSNS',
#  'D_0_4_FPT_T',
#  'Male_Lone_Parent_Employed_Worked_Full_Time',
#  'Male_Lone_Parent_Employed_Worked_Part_Time',
#  'Male_Lone_Parent_Employed_Away_From_Work',
#  'Male_Lone_Parent_Hours_Worked_Not_Stated',
#  'Male_Lone_Parent_Total_Employed',
#  'Male_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Male_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Male_Lone_Parent_Total_Unemployed',
#  'Male_Lone_Parent_Total_Labour_Force',
#  'Male_Lone_Parent_Not_In_The_Labour_Force',
#  'Male_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Male_Lone_Parent_Total',
#  'Female_Lone_Parent_Employed_Worked_Full_Time',
#  'Female_Lone_Parent_Employed_Worked_Part_Time',
#  'Female_Lone_Parent_Employed_Away_From_Work',
#  'Female_Lone_Parent_Hours_Worked_Not_Stated',
#  'Female_Lone_Parent_Total_Employed',
#  'Female_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Female_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Female_Lone_Parent_Total_Unemployed',
#  'Female_Lone_Parent_Total_Labour_Force',
#  'Female_Lone_Parent_Not_In_The_Labour_Force',
#  'Female_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Female_Lone_Parent_Total',
#  'Total_Lone_Parents_Employed_Worked_Full_Time',
#  'Total_Lone_Parents_Employed_Worked_Part_Time',
#  'Total_Lone_Parents_Employed_Away_From_Work',
#  'Total_Lone_Parents_Hours_Worked_Not_Stated',
#  'Total_Lone_Parents_Total_Employed',
#  'Total_Lone_Parents_Unemployed_Looking_For_Full_Time_Work',
#  'Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work',
#  'Total_Lone_Parents_Total_Unemployed',
#  'Total_Lone_Parents_Total_Labour_Force',
#  'Total_Lone_Parents_Not_In_The_Labour_Force',
#  'Total_Lone_Parents_Labour_Force_Status_Not_Stated',
#  'Total_Lone_Parents_Total',
#  'SA2_name',
#  'Index of Relative Socio-economic Disadvantage_score',
#  'Index of Relative Socio-economic Disadvantage_decile',
#  'Index of Relative Socio-economic Adv and Disadv_score',
#  'Index of Relative Socio-economic Adv and Disadv_decile',
#  'Index of Economic Resources_score',
#  'Index of Economic Resources_decile',
#  'Index of Education and Occupation_score',
#  'Index of Education and Occupation_decile',
#  'Usual Resident Population',
#  'code',
#  'name',
#  'total',
#  'on_track',
#  'at_risk',
#  'vulnerable',
#  'vulnerable_percentage']

# %%
sample_df = df.drop(columns = ["Unnamed: 0", "SA2_MAINCODE_2016", "SA2_name", "Usual Resident Population", "code", "name", 
                              "total", "at_risk", "on_track", "vulnerable_percentage",
                              "Index of Relative Socio-economic Disadvantage_decile",
                              "Index of Relative Socio-economic Adv and Disadv_decile",
                              "Index of Economic Resources_decile",
                              "Index of Education and Occupation_decile"
                               ])

# %%
target = sample_df["vulnerable"]

# %%
data = sample_df.drop("vulnerable", axis=1)
feature_names = data.columns
data
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 0                   64                 12                  0
# 1                   49                 10                  0
# 2                   86                 16                  0
# 3                   66                 15                  3
# 4                   30                  0                  0
# ..                 ...                ...                ...
# 422                  9                  0                  0
# 423                 35                  3                  0
# 424                 39                  3                  0
# 425                 67                 12                  0
# 426                 33                 10                  0
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 0                     3                74                    0
# 1                     0                59                    0
# 2                     0               107                    3
# 3                     0                88                    4
# 4                     0                34                    0
# ..                  ...               ...                  ...
# 422                   0                10                    0
# 423                   0                39                    0
# 424                   3                45                    0
# 425                   0                84                    3
# 426                   0                46                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 0                      0                 0                 78
# 1                      0                 0                 59
# 2                      0                 3                104
# 3                      3                 5                 92
# 4                      0                 0                 32
# ..                   ...               ...                ...
# 422                    0                 0                 10
# 423                    0                 0                 39
# 424                    0                 0                 45
# 425                    0                 3                 89
# 426                    0                 0                 46
#
#      D_0_4_FPEFT_MPNLF  ...  \
# 0                    3  ...
# 1                    0  ...
# 2                    9  ...
# 3                   10  ...
# 4                    3  ...
# ..                 ...  ...
# 422                  0  ...
# 423                  3  ...
# 424                  3  ...
# 425                 16  ...
# 426                  5  ...
#
#      Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work  \
# 0                                                    3
# 1                                                    0
# 2                                                   12
# 3                                                   17
# 4                                                    0
# ..                                                 ...
# 422                                                  0
# 423                                                  0
# 424                                                  0
# 425                                                  3
# 426                                                  0
#
#      Total_Lone_Parents_Total_Unemployed  \
# 0                                      3
# 1                                      9
# 2                                     18
# 3                                     22
# 4                                      0
# ..                                   ...
# 422                                    0
# 423                                    0
# 424                                    0
# 425                                    6
# 426                                    0
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 0                                       34
# 1                                       39
# 2                                       87
# 3                                      126
# 4                                        9
# ..                                     ...
# 422                                     12
# 423                                     19
# 424                                     24
# 425                                     80
# 426                                     41
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 0                                            47
# 1                                            35
# 2                                           110
# 3                                           261
# 4                                            17
# ..                                          ...
# 422                                           3
# 423                                          14
# 424                                          27
# 425                                         131
# 426                                          68
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    5
# 4                                                    0
# ..                                                 ...
# 422                                                  0
# 423                                                  0
# 424                                                  0
# 425                                                  7
# 426                                                  3
#
#      Total_Lone_Parents_Total  \
# 0                          82
# 1                          77
# 2                         198
# 3                         388
# 4                          29
# ..                        ...
# 422                        14
# 423                        34
# 424                        50
# 425                       217
# 426                       112
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 0                                                 1045
# 1                                                 1035
# 2                                                  999
# 3                                                  926
# 4                                                 1066
# ..                                                 ...
# 422                                                995
# 423                                               1008
# 424                                               1020
# 425                                                986
# 426                                                986
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 0                                                 1025
# 1                                                 1037
# 2                                                  983
# 3                                                  912
# 4                                                 1051
# ..                                                 ...
# 422                                                976
# 423                                                995
# 424                                                998
# 425                                                958
# 426                                                966
#
#      Index of Economic Resources_score  \
# 0                                 1037
# 1                                  975
# 2                                  972
# 3                                  904
# 4                                 1048
# ..                                 ...
# 422                                988
# 423                               1037
# 424                               1026
# 425                                976
# 426                                961
#
#      Index of Education and Occupation_score
# 0                                     1022.0
# 1                                     1088.0
# 2                                     1010.0
# 3                                      946.0
# 4                                     1065.0
# ..                                       ...
# 422                                   1010.0
# 423                                   1003.0
# 424                                   1009.0
# 425                                    952.0
# 426                                    981.0
#
# [427 rows x 184 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100) # parameters of the model - change estimators to see if you can get a better outcome

# %% [markdown]
# ### Scaling

# %%
# Now, we fit our StandardScaler model to our training data. We can apply this StandardScaler model to any future data. Note that we use this fit/transform approach so that we isolate our testing data from the training data that we use to fit our model. Otherwise, we might bias our model to the testing data.
# If working with different units of measurement - allows us to 
# standardised the scaling - reduces the magnitude of numbers while still maintaining the
# truth of the relative distance between our numerical observations
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train.to_numpy().reshape(-1, 1))

# when you express different attributes on different scales of magnitude - for the scales
# that result in bigger numbers - your machine learning algorithm may hon in
# on those bigger values because there is more variety within that column - to remove
# that biasing effect of these large numbers we rescale our values - reduce the amount of 
# variety in that column between the largest value and the smallest value.
# reducing the magnitude of the variance within our data.

# %%
# general standard when building a model is to apply some scaling. (mm and kg - rescale mm to m)
# Create versions of our x and y data that have been rescaled
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test) # apply same trasformation/scaling to our test data
y_train_scaled = y_scaler.transform(y_train.to_numpy().reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.to_numpy().reshape(-1, 1))

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["Total_Lone_Parents_Total"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["Total_Lone_Parents_Total"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])
# scaled data - same shape just reduced the space that our values fall into - more compact
# rescaling the data - still preserves the underlying truth of the data
# relative positioning of our data remains true

# %%
rf = rf.fit(X_train_scaled, y_train)

# %%
# These are the predictor values
# y_test - values you already know
predict_values = rf.predict(X_test_scaled)
predict_values
# Out:
# array([ 2.5 ,  6.45, 19.22,  2.5 , 48.85,  4.92,  7.16,  3.7 ,  2.62,
#         9.57, 21.68, 17.53,  3.52,  3.08, 12.78,  6.56, 19.  ,  1.79,
#         4.96,  2.29,  9.34, 26.83,  6.79, 12.85,  5.71,  6.76,  6.42,
#         4.28,  6.92, 17.53,  2.53, 14.98,  5.74,  3.06,  2.5 , 17.65,
#         9.74,  4.65,  6.26,  3.76, 30.6 ,  1.98,  8.34, 18.13,  4.7 ,
#         4.45,  4.12, 14.6 ,  4.71,  1.47, 11.79,  2.65, 13.11,  8.58,
#        10.11,  5.47, 25.6 ,  5.21,  5.06,  7.55,  2.92, 11.63,  3.96,
#         2.68, 35.44,  4.72,  4.33,  7.62,  4.96, 14.62, 25.46, 10.12,
#        10.51,  7.1 , 16.61,  4.52,  3.9 , 15.95, 13.72,  4.39,  5.38,
#        15.44,  2.35, 17.96, 15.67, 20.16])

# %%
# Mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, predict_values)
# Out:
# 638882737836280.1

# %%
results = sorted(zip(rf.feature_importances_, feature_names), reverse=True)
results
# Out:
# [(0.20703576326752313, 'Total_Lone_Parents_Total'),
#  (0.15217370140708802, 'Female_Lone_Parent_Total'),
#  (0.07278336709529525, 'D_0_4_FPNLF_T'),
#  (0.072024153249629, 'Female_Lone_Parent_Not_In_The_Labour_Force'),
#  (0.0574414089786044, 'Total_Lone_Parents_Not_In_The_Labour_Force'),
#  (0.040301093256830296, 'D_0_4_FPNLF_MPEPT'),
#  (0.025622799269254256, 'D_0_4_FPT_MPNLF'),
#  (0.024352851963632224, 'D_0_4_FPT_MPULFTW'),
#  (0.024175398105238433, 'D_0_4_FPT_MPEPT'),
#  (0.015346276520310977, 'D_0_4_FPULFTW_MPTLF'),
#  (0.014290998915639529, 'D_0_4_FPT_MPUT'),
#  (0.012904760310340942, 'D_0_4_FPNLF_MPUEmpLfFTW'),
#  (0.011805620089540359, 'D_0_4_FPNLF_MPNLF'),
#  (0.010792224838054261, 'Total_Lone_Parents_Total_Unemployed'),
#  (0.010489355457970055, 'D_0_4_FPNLF_MPTLF'),
#  (0.010280251240704981,
#   'Female_Lone_Parent_Unemployed_Looking_For_Part_Time_Work'),
#  (0.009484748704200359, 'Index of Education and Occupation_score'),
#  (0.00879803287449081, 'D_0_4_FPEPT_MPULFTW'),
#  (0.008687462603739616, 'Total_Lone_Parents_Total_Labour_Force'),
#  (0.008519804164099315, 'D_0_4_FPNLF_MPLFSNS'),
#  (0.007615514915209382, 'D_0_4_FPET_MPULFTW'),
#  (0.0069804864138596065, 'D_0_4_FPT_MPULPTW'),
#  (0.00597402416730378, 'D_0_4_FPNLF_MPUT'),
#  (0.005694840054079836, 'D_0_4_FPTLF_MPNLF'),
#  (0.005299298317622323,
#   'Total_Lone_Parents_Unemployed_Looking_For_Full_Time_Work'),
#  (0.0049843833903623425, 'D_0_4_FPULFTW_T'),
#  (0.004341241517286954, 'Index of Economic Resources_score'),
#  (0.004298393643612601,
#   'Index of Relative Socio-economic Adv and Disadv_score'),
#  (0.004220250367277604, 'D_0_4_FPULFTW_MPEFT'),
#  (0.004132414467497577, 'D_0_4_FPUT_MPULFTW'),
#  (0.004109689438613309, 'Male_Lone_Parent_Total'),
#  (0.003982553970623548, 'D_0_4_FPEPT_MPUT'),
#  (0.003837139128841508, 'D_0_4_FPEPT_MPNLF'),
#  (0.003639892473472811,
#   'Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work'),
#  (0.003177508225269957, 'Female_Lone_Parent_Labour_Force_Status_Not_Stated'),
#  (0.003129219974019493, 'Index of Relative Socio-economic Disadvantage_score'),
#  (0.0031101826259417337, 'D_0_4_FPUT_T'),
#  (0.0029752034585609753, 'D_0_4_FPT_MPEAW'),
#  (0.002940308356875153, 'Female_Lone_Parent_Total_Labour_Force'),
#  (0.0028093459736044735, 'D_0_4_FPULPTW_MPTLF'),
#  (0.002724901243090206, 'D_0_4_FPTLF_MPUT'),
#  (0.002716358315169898, 'D_0_4_FPEFT_MPNLF'),
#  (0.002642656143248201, 'D_0_4_FPNLF_MPEAW'),
#  (0.002614787242324901, 'Male_Lone_Parent_Total_Unemployed'),
#  (0.0025260205571138923, 'Male_Lone_Parent_Total_Employed'),
#  (0.0024757174630973106, 'D_0_4_FPULFTW_MPET'),
#  (0.002450587537646266, 'D_0_4_FPEFT_MPEPT'),
#  (0.0024169496397978443, 'Female_Lone_Parent_Employed_Worked_Part_Time'),
#  (0.0023270610438342046, 'Female_Lone_Parent_Employed_Worked_Full_Time'),
#  (0.00222233255831894, 'Female_Lone_Parent_Total_Unemployed'),
#  (0.002135317792397821, 'D_0_4_FPULFTW_MPUT'),
#  (0.0019516010681424343, 'D_0_4_FPLFSNS_MPNLF'),
#  (0.0019358828010358322, 'D_0_4_FPEPT_MPEHNS'),
#  (0.0019311162049286444, 'Total_Lone_Parents_Labour_Force_Status_Not_Stated'),
#  (0.001892464516813767, 'D_0_4_FPEPT_MPEAW'),
#  (0.0018747111499931557, 'D_0_4_FPTLF_MPEHNS'),
#  (0.0017967197877632821, 'D_0_4_FPNLF_MPET'),
#  (0.0017928699195020304, 'D_0_4_FPEAW_MPEPT'),
#  (0.0016940590891895283, 'D_0_4_FPUT_MPEPT'),
#  (0.0016768990058219258, 'D_0_4_FPNLF_MPUEmpLfPTW'),
#  (0.0016722854050303618, 'D_0_4_FPUT_MPEFT'),
#  (0.0016180127314383026, 'D_0_4_FPUT_MPET'),
#  (0.0015719063889127881, 'Total_Lone_Parents_Employed_Worked_Full_Time'),
#  (0.0015460497322228824, 'Male_Lone_Parent_Not_In_The_Labour_Force'),
#  (0.0015440790645730974, 'D_0_4_FPLFSNS_T'),
#  (0.0014326690047806198, 'D_0_4_FPHNS_T'),
#  (0.0014289401174964755, 'D_0_4_FPT_MPEHNS'),
#  (0.0014020914176792543, 'D_0_4_FPHNS_MPEHNS'),
#  (0.0013640606467004205, 'D_0_4_FPTLF_MPULFTW'),
#  (0.0013575928875293824, 'D_0_4_FPEAW_MPEFT'),
#  (0.0013510349757615352, 'D_0_4_FPT_MPLFSNS'),
#  (0.0013310236520117566, 'D_0_4_FPEFT_MPTLF'),
#  (0.001330848387037584, 'D_0_4_FPULPTW_T'),
#  (0.0012712538409129902, 'D_0_4_FPLFSNS_MPLFSNS'),
#  (0.0012700794652300226, 'D_0_4_FPEAW_MPEAW'),
#  (0.0012253436210809506, 'D_0_4_FPULPTW_MPET'),
#  (0.0012063909195743586, 'D_0_4_FPEFT_MPEHNS'),
#  (0.0011729318045396436, 'Total_Lone_Parents_Total_Employed'),
#  (0.0011718039006203326, 'D_0_4_FPET_MPULPTW'),
#  (0.0011505916330162623, 'D_0_4_FPEPT_MPEPT'),
#  (0.001133440783769227, 'Total_Lone_Parents_Employed_Worked_Part_Time'),
#  (0.0011157417227751925, 'D_0_4_FPNLF_MP_E_HNS'),
#  (0.0010865072291801547, 'D_0_4_FPULPTW_MPEPT'),
#  (0.001084148299791951, 'Male_Lone_Parent_Employed_Worked_Part_Time'),
#  (0.0010789763941357327, 'D_0_4_FPULFTW_MPEPT'),
#  (0.0010251204955083592, 'D_0_4_FPET_MPUT'),
#  (0.0010014506591272073, 'D_0_4_FPUT_MPUT'),
#  (0.000893013429317075, 'D_0_4_FPTLF_MPEAW'),
#  (0.0008875817816050342, 'D_0_4_FPEPT_MPEFT'),
#  (0.0008825718661610339, 'D_0_4_FPET_MPNLF'),
#  (0.0008799515681728143, 'D_0_4_FPET_MPEHNS'),
#  (0.0008710030406726064, 'D_0_4_FPEPT_MPET'),
#  (0.0008542570731270963, 'D_0_4_FPHNS_MPET'),
#  (0.0008462858129142399, 'Female_Lone_Parent_Employed_Away_From_Work'),
#  (0.0008363260547456355, 'Female_Lone_Parent_Hours_Worked_Not_Stated'),
#  (0.0008340160783316368, 'D_0_4_FPUT_MPULPTW'),
#  (0.0008337036490784331, 'D_0_4_FPET_T'),
#  (0.0008273516003960791, 'Male_Lone_Parent_Employed_Worked_Full_Time'),
#  (0.0007848971868854046, 'D_0_4_FPULPTW_MPEFT'),
#  (0.0007840080637069576, 'D_0_4_FPEPT_T'),
#  (0.0007776181776656585, 'D_0_4_FPULPTW_MPUT'),
#  (0.0007689398519808254, 'D_0_4_FPULPTW_MPULFTW'),
#  (0.000745434295460025, 'D_0_4_FPTLF_MPEPT'),
#  (0.0007337067165620853, 'D_0_4_FPET_MPEPT'),
#  (0.0007295688629051603, 'Male_Lone_Parent_Total_Labour_Force'),
#  (0.0007106928310674811, 'D_0_4_FPEFT_MPUT'),
#  (0.0007012205010477234, 'D_0_4_FPEFT_MPET'),
#  (0.0006939334101855485, 'Female_Lone_Parent_Total_Employed'),
#  (0.0006911270712965277, 'D_0_4_FPHNS_MPEFT'),
#  (0.0006555510161058411, 'Total_Lone_Parents_Employed_Away_From_Work'),
#  (0.0006494343200782037, 'D_0_4_FPEPT_MPTLF'),
#  (0.0006457319688349078, 'D_0_4_FPET_MPEAW'),
#  (0.0006293057626706269, 'D_0_4_FPLFSNS_MPTLF'),
#  (0.0006284279848498004, 'D_0_4_FPET_MPET'),
#  (0.0006241843308391699, 'D_0_4_FPEAW_MPNLF'),
#  (0.0006065966756551517, 'D_0_4_FPEAW_T'),
#  (0.0005620420451612765, 'D_0_4_FPNLF_MPEFT'),
#  (0.0005556551548956026, 'D_0_4_FPEAW_MPET'),
#  (0.000553555194347983, 'D_0_4_FPUT_MPNLF'),
#  (0.0005517601112768654,
#   'Male_Lone_Parent_Unemployed_Looking_For_Part_Time_Work'),
#  (0.0005429846990335769, 'D_0_4_FPHNS_MPTLF'),
#  (0.0005343750494555815, 'D_0_4_FPEFT_T'),
#  (0.0005309968437910645,
#   'Male_Lone_Parent_Unemployed_Looking_For_Full_Time_Work'),
#  (0.0005145229609051045, 'D_0_4_FPEAW_MPTLF'),
#  (0.0005092803275098988, 'Male_Lone_Parent_Hours_Worked_Not_Stated'),
#  (0.000505526487070089, 'D_0_4_FPT_MPTLF'),
#  (0.0004945842302418774, 'D_0_4_FPEFT_MPULFTW'),
#  (0.0004933703042494221, 'D_0_4_FPEFT_MPEAW'),
#  (0.00048364283864485674, 'D_0_4_FPTLF_MPTLF'),
#  (0.000481349110788918, 'D_0_4_FPT_MPET'),
#  (0.0004347419321605597, 'D_0_4_FPLFSNS_MPET'),
#  (0.0004265299711844703, 'D_0_4_FPEFT_MPEFT'),
#  (0.00041400868934324237, 'D_0_4_FPET_MPEFT'),
#  (0.00038835991694554793, 'D_0_4_FPUT_MPTLF'),
#  (0.0003853125803767628, 'D_0_4_FPTLF_MPULPTW'),
#  (0.0003791082557830516, 'D_0_4_FPT_MPEFT'),
#  (0.0003676232564626444, 'D_0_4_FPTLF_MPEFT'),
#  (0.000352443684736754, 'D_0_4_FPT_T'),
#  (0.00033068274975539595, 'D_0_4_FPTLF_MPET'),
#  (0.0003088100724187946, 'D_0_4_FPULFTW_MPULFTW'),
#  (0.0002860967512352673, 'D_0_4_FPUT_MP_E_HNS'),
#  (0.00028448947624024783, 'D_0_4_FPEPT_MPULPTW'),
#  (0.0002826914727076074, 'D_0_4_FPUT_MPEAW'),
#  (0.00024521346819593876, 'D_0_4_FPET_MPTLF'),
#  (0.00021207399294818658, 'D_0_4_FPTLF_MPLFSNS'),
#  (0.0002059147333216783,
#   'Female_Lone_Parent_Unemployed_Looking_For_Full_Time_Work'),
#  (0.00019373796672360083, 'D_0_4_FPLFSNS_MP_E_HNS'),
#  (0.0001832384466001351, 'D_0_4_FPLFSNS_MPEFT'),
#  (0.000180231237594283, 'D_0_4_FPHNS_MPEPT'),
#  (0.0001735930435332007, 'D_0_4_FPTLF_T'),
#  (0.0001730309424501606, 'Total_Lone_Parents_Hours_Worked_Not_Stated'),
#  (0.00017031397964635816, 'D_0_4_FPEAW_MPEHNS'),
#  (0.00012657101099985358, 'D_0_4_FPHNS_MPLFSNS'),
#  (0.00011449309839073666, 'D_0_4_FPEFT_MPULPTW'),
#  (0.00011143848385891074, 'D_0_4_FPET_MPLFSNS'),
#  (9.49476635109823e-05, 'D_0_4_FPULFTW_MPNLF'),
#  (8.639365924665725e-05, 'D_0_4_FPULPTW_MPNLF'),
#  (8.446612394300479e-05, 'D_0_4_FPEAW_MPUT'),
#  (7.611895333251138e-05, 'D_0_4_FPULPTW_MPULPTW'),
#  (5.290294118023668e-05, 'D_0_4_FPHNS_MPNLF'),
#  (4.7492922415291906e-05, 'D_0_4_FPEAW_MPULFTW'),
#  (4.357790967007614e-05, 'D_0_4_FPLFSNS_MPULPTW'),
#  (4.209743806445474e-05, 'D_0_4_FPULFTW_MPULPTW'),
#  (2.7692305181659476e-05, 'D_0_4_FPLFSNS_MPULFTW'),
#  (2.5486160093142383e-05, 'D_0_4_FPLFSNS_MPEPT'),
#  (1.3464090721912821e-05, 'D_0_4_FPHNS_MPULPTW'),
#  (1.2535155132879073e-05, 'Male_Lone_Parent_Employed_Away_From_Work'),
#  (1.0020716140911143e-05, 'D_0_4_FPHNS_MPUT'),
#  (9.127837043136546e-06, 'D_0_4_FPULPTW_MPEAW'),
#  (5.905868129500389e-06, 'D_0_4_FPULFTW_MP_EAW'),
#  (3.560197003770537e-06, 'Male_Lone_Parent_Labour_Force_Status_Not_Stated'),
#  (2.4766877588465546e-06, 'D_0_4_FPUT_MPLFSNS'),
#  (1.4979841724668423e-06, 'D_0_4_FPULFTW_MP_E_HW_NS'),
#  (1.2070189746214529e-06, 'D_0_4_FPULPTW_MPLFSNS'),
#  (8.975865631316606e-07, 'D_0_4_FPEAW_MPLFSNS'),
#  (7.119772208526395e-07, 'D_0_4_FPEPT_MPLFSNS'),
#  (5.321716706386319e-07, 'D_0_4_FPEFT_MPLFSNS'),
#  (4.1650084736578457e-07, 'D_0_4_FPHNS_MPEAW'),
#  (1.4218611612199273e-07, 'D_0_4_FPLFSNS_MPEAW'),
#  (1.4094077346312555e-07, 'D_0_4_FPHNS_MPULFTW'),
#  (0.0, 'D_0_4_FPULPTW_MPEm_HW_NS'),
#  (0.0, 'D_0_4_FPULFTW_MPLFSNS'),
#  (0.0, 'D_0_4_FPLFSNS_MPUT'),
#  (0.0, 'D_0_4_FPEAW_MPULPTW')]

# %%
sum_results = 0
for i in results:
    sum_results += i[0]
    
sum_results
# Out:
# 1.0
