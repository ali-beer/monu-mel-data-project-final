# %%
from sklearn import tree
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(os.path.join("emotional_abs_merged.csv"))

list(df.columns)
# Out:
# ['Unnamed: 0',
#  'SA2_MAINCODE_2016',
#  'D_0_4_FPEFT_MPEFT',
#  'D_0_4_FPEFT_MPEPT',
#  'D_0_4_FPEFT_MPEAW',
#  'D_0_4_FPEFT_MPEHNS',
#  'D_0_4_FPEFT_MPET',
#  'D_0_4_FPEFT_MPULFTW',
#  'D_0_4_FPEFT_MPULPTW',
#  'D_0_4_FPEFT_MPUT',
#  'D_0_4_FPEFT_MPTLF',
#  'D_0_4_FPEFT_MPNLF',
#  'D_0_4_FPEFT_MPLFSNS',
#  'D_0_4_FPEFT_T',
#  'D_0_4_FPEPT_MPEFT',
#  'D_0_4_FPEPT_MPEPT',
#  'D_0_4_FPEPT_MPEAW',
#  'D_0_4_FPEPT_MPEHNS',
#  'D_0_4_FPEPT_MPET',
#  'D_0_4_FPEPT_MPULFTW',
#  'D_0_4_FPEPT_MPULPTW',
#  'D_0_4_FPEPT_MPUT',
#  'D_0_4_FPEPT_MPTLF',
#  'D_0_4_FPEPT_MPNLF',
#  'D_0_4_FPEPT_MPLFSNS',
#  'D_0_4_FPEPT_T',
#  'D_0_4_FPEAW_MPEFT',
#  'D_0_4_FPEAW_MPEPT',
#  'D_0_4_FPEAW_MPEAW',
#  'D_0_4_FPEAW_MPEHNS',
#  'D_0_4_FPEAW_MPET',
#  'D_0_4_FPEAW_MPULFTW',
#  'D_0_4_FPEAW_MPULPTW',
#  'D_0_4_FPEAW_MPUT',
#  'D_0_4_FPEAW_MPTLF',
#  'D_0_4_FPEAW_MPNLF',
#  'D_0_4_FPEAW_MPLFSNS',
#  'D_0_4_FPEAW_T',
#  'D_0_4_FPHNS_MPEFT',
#  'D_0_4_FPHNS_MPEPT',
#  'D_0_4_FPHNS_MPEAW',
#  'D_0_4_FPHNS_MPEHNS',
#  'D_0_4_FPHNS_MPET',
#  'D_0_4_FPHNS_MPULFTW',
#  'D_0_4_FPHNS_MPULPTW',
#  'D_0_4_FPHNS_MPUT',
#  'D_0_4_FPHNS_MPTLF',
#  'D_0_4_FPHNS_MPNLF',
#  'D_0_4_FPHNS_MPLFSNS',
#  'D_0_4_FPHNS_T',
#  'D_0_4_FPET_MPEFT',
#  'D_0_4_FPET_MPEPT',
#  'D_0_4_FPET_MPEAW',
#  'D_0_4_FPET_MPEHNS',
#  'D_0_4_FPET_MPET',
#  'D_0_4_FPET_MPULFTW',
#  'D_0_4_FPET_MPULPTW',
#  'D_0_4_FPET_MPUT',
#  'D_0_4_FPET_MPTLF',
#  'D_0_4_FPET_MPNLF',
#  'D_0_4_FPET_MPLFSNS',
#  'D_0_4_FPET_T',
#  'D_0_4_FPULFTW_MPEFT',
#  'D_0_4_FPULFTW_MPEPT',
#  'D_0_4_FPULFTW_MP_EAW',
#  'D_0_4_FPULFTW_MP_E_HW_NS',
#  'D_0_4_FPULFTW_MPET',
#  'D_0_4_FPULFTW_MPULFTW',
#  'D_0_4_FPULFTW_MPULPTW',
#  'D_0_4_FPULFTW_MPUT',
#  'D_0_4_FPULFTW_MPTLF',
#  'D_0_4_FPULFTW_MPNLF',
#  'D_0_4_FPULFTW_MPLFSNS',
#  'D_0_4_FPULFTW_T',
#  'D_0_4_FPULPTW_MPEFT',
#  'D_0_4_FPULPTW_MPEPT',
#  'D_0_4_FPULPTW_MPEAW',
#  'D_0_4_FPULPTW_MPEm_HW_NS',
#  'D_0_4_FPULPTW_MPET',
#  'D_0_4_FPULPTW_MPULFTW',
#  'D_0_4_FPULPTW_MPULPTW',
#  'D_0_4_FPULPTW_MPUT',
#  'D_0_4_FPULPTW_MPTLF',
#  'D_0_4_FPULPTW_MPNLF',
#  'D_0_4_FPULPTW_MPLFSNS',
#  'D_0_4_FPULPTW_T',
#  'D_0_4_FPUT_MPEFT',
#  'D_0_4_FPUT_MPEPT',
#  'D_0_4_FPUT_MPEAW',
#  'D_0_4_FPUT_MP_E_HNS',
#  'D_0_4_FPUT_MPET',
#  'D_0_4_FPUT_MPULFTW',
#  'D_0_4_FPUT_MPULPTW',
#  'D_0_4_FPUT_MPUT',
#  'D_0_4_FPUT_MPTLF',
#  'D_0_4_FPUT_MPNLF',
#  'D_0_4_FPUT_MPLFSNS',
#  'D_0_4_FPUT_T',
#  'D_0_4_FPTLF_MPEFT',
#  'D_0_4_FPTLF_MPEPT',
#  'D_0_4_FPTLF_MPEAW',
#  'D_0_4_FPTLF_MPEHNS',
#  'D_0_4_FPTLF_MPET',
#  'D_0_4_FPTLF_MPULFTW',
#  'D_0_4_FPTLF_MPULPTW',
#  'D_0_4_FPTLF_MPUT',
#  'D_0_4_FPTLF_MPTLF',
#  'D_0_4_FPTLF_MPNLF',
#  'D_0_4_FPTLF_MPLFSNS',
#  'D_0_4_FPTLF_T',
#  'D_0_4_FPNLF_MPEFT',
#  'D_0_4_FPNLF_MPEPT',
#  'D_0_4_FPNLF_MPEAW',
#  'D_0_4_FPNLF_MP_E_HNS',
#  'D_0_4_FPNLF_MPET',
#  'D_0_4_FPNLF_MPUEmpLfFTW',
#  'D_0_4_FPNLF_MPUEmpLfPTW',
#  'D_0_4_FPNLF_MPUT',
#  'D_0_4_FPNLF_MPTLF',
#  'D_0_4_FPNLF_MPNLF',
#  'D_0_4_FPNLF_MPLFSNS',
#  'D_0_4_FPNLF_T',
#  'D_0_4_FPLFSNS_MPEFT',
#  'D_0_4_FPLFSNS_MPEPT',
#  'D_0_4_FPLFSNS_MPEAW',
#  'D_0_4_FPLFSNS_MP_E_HNS',
#  'D_0_4_FPLFSNS_MPET',
#  'D_0_4_FPLFSNS_MPULFTW',
#  'D_0_4_FPLFSNS_MPULPTW',
#  'D_0_4_FPLFSNS_MPUT',
#  'D_0_4_FPLFSNS_MPTLF',
#  'D_0_4_FPLFSNS_MPNLF',
#  'D_0_4_FPLFSNS_MPLFSNS',
#  'D_0_4_FPLFSNS_T',
#  'D_0_4_FPT_MPEFT',
#  'D_0_4_FPT_MPEPT',
#  'D_0_4_FPT_MPEAW',
#  'D_0_4_FPT_MPEHNS',
#  'D_0_4_FPT_MPET',
#  'D_0_4_FPT_MPULFTW',
#  'D_0_4_FPT_MPULPTW',
#  'D_0_4_FPT_MPUT',
#  'D_0_4_FPT_MPTLF',
#  'D_0_4_FPT_MPNLF',
#  'D_0_4_FPT_MPLFSNS',
#  'D_0_4_FPT_T',
#  'Male_Lone_Parent_Employed_Worked_Full_Time',
#  'Male_Lone_Parent_Employed_Worked_Part_Time',
#  'Male_Lone_Parent_Employed_Away_From_Work',
#  'Male_Lone_Parent_Hours_Worked_Not_Stated',
#  'Male_Lone_Parent_Total_Employed',
#  'Male_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Male_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Male_Lone_Parent_Total_Unemployed',
#  'Male_Lone_Parent_Total_Labour_Force',
#  'Male_Lone_Parent_Not_In_The_Labour_Force',
#  'Male_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Male_Lone_Parent_Total',
#  'Female_Lone_Parent_Employed_Worked_Full_Time',
#  'Female_Lone_Parent_Employed_Worked_Part_Time',
#  'Female_Lone_Parent_Employed_Away_From_Work',
#  'Female_Lone_Parent_Hours_Worked_Not_Stated',
#  'Female_Lone_Parent_Total_Employed',
#  'Female_Lone_Parent_Unemployed_Looking_For_Full_Time_Work',
#  'Female_Lone_Parent_Unemployed_Looking_For_Part_Time_Work',
#  'Female_Lone_Parent_Total_Unemployed',
#  'Female_Lone_Parent_Total_Labour_Force',
#  'Female_Lone_Parent_Not_In_The_Labour_Force',
#  'Female_Lone_Parent_Labour_Force_Status_Not_Stated',
#  'Female_Lone_Parent_Total',
#  'Total_Lone_Parents_Employed_Worked_Full_Time',
#  'Total_Lone_Parents_Employed_Worked_Part_Time',
#  'Total_Lone_Parents_Employed_Away_From_Work',
#  'Total_Lone_Parents_Hours_Worked_Not_Stated',
#  'Total_Lone_Parents_Total_Employed',
#  'Total_Lone_Parents_Unemployed_Looking_For_Full_Time_Work',
#  'Total_Lone_Parents_Unemployed_Looking_For_Part_Time_Work',
#  'Total_Lone_Parents_Total_Unemployed',
#  'Total_Lone_Parents_Total_Labour_Force',
#  'Total_Lone_Parents_Not_In_The_Labour_Force',
#  'Total_Lone_Parents_Labour_Force_Status_Not_Stated',
#  'Total_Lone_Parents_Total',
#  'SA2_name',
#  'Index of Relative Socio-economic Disadvantage_score',
#  'Index of Relative Socio-economic Disadvantage_decile',
#  'Index of Relative Socio-economic Adv and Disadv_score',
#  'Index of Relative Socio-economic Adv and Disadv_decile',
#  'Index of Economic Resources_score',
#  'Index of Economic Resources_decile',
#  'Index of Education and Occupation_score',
#  'Index of Education and Occupation_decile',
#  'Usual Resident Population',
#  'code',
#  'name',
#  'total',
#  'on_track',
#  'at_risk',
#  'vulnerable',
#  'vulnerable_percentage']

# %%
sample_df = df.drop(columns = ["Unnamed: 0", "SA2_MAINCODE_2016", "SA2_name", "Usual Resident Population", "name", 
                              "total", "at_risk", "on_track", "vulnerable_percentage",
                              "Index of Relative Socio-economic Disadvantage_decile",
                              "Index of Relative Socio-economic Adv and Disadv_decile",
                              "Index of Economic Resources_decile",
                              "Index of Education and Occupation_decile"
                               ])

# %%
target = sample_df["vulnerable"]

# %%
data = sample_df.drop("vulnerable", axis=1)
feature_names = data.columns
data
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 0                   64                 12                  0
# 1                   49                 10                  0
# 2                   86                 16                  0
# 3                   66                 15                  3
# 4                   30                  0                  0
# ..                 ...                ...                ...
# 422                  9                  0                  0
# 423                 35                  3                  0
# 424                 39                  3                  0
# 425                 67                 12                  0
# 426                 33                 10                  0
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 0                     3                74                    0
# 1                     0                59                    0
# 2                     0               107                    3
# 3                     0                88                    4
# 4                     0                34                    0
# ..                  ...               ...                  ...
# 422                   0                10                    0
# 423                   0                39                    0
# 424                   3                45                    0
# 425                   0                84                    3
# 426                   0                46                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 0                      0                 0                 78
# 1                      0                 0                 59
# 2                      0                 3                104
# 3                      3                 5                 92
# 4                      0                 0                 32
# ..                   ...               ...                ...
# 422                    0                 0                 10
# 423                    0                 0                 39
# 424                    0                 0                 45
# 425                    0                 3                 89
# 426                    0                 0                 46
#
#      D_0_4_FPEFT_MPNLF  ...  Total_Lone_Parents_Total_Unemployed  \
# 0                    3  ...                                    3
# 1                    0  ...                                    9
# 2                    9  ...                                   18
# 3                   10  ...                                   22
# 4                    3  ...                                    0
# ..                 ...  ...                                  ...
# 422                  0  ...                                    0
# 423                  3  ...                                    0
# 424                  3  ...                                    0
# 425                 16  ...                                    6
# 426                  5  ...                                    0
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 0                                       34
# 1                                       39
# 2                                       87
# 3                                      126
# 4                                        9
# ..                                     ...
# 422                                     12
# 423                                     19
# 424                                     24
# 425                                     80
# 426                                     41
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 0                                            47
# 1                                            35
# 2                                           110
# 3                                           261
# 4                                            17
# ..                                          ...
# 422                                           3
# 423                                          14
# 424                                          27
# 425                                         131
# 426                                          68
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    5
# 4                                                    0
# ..                                                 ...
# 422                                                  0
# 423                                                  0
# 424                                                  0
# 425                                                  7
# 426                                                  3
#
#      Total_Lone_Parents_Total  \
# 0                          82
# 1                          77
# 2                         198
# 3                         388
# 4                          29
# ..                        ...
# 422                        14
# 423                        34
# 424                        50
# 425                       217
# 426                       112
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 0                                                 1045
# 1                                                 1035
# 2                                                  999
# 3                                                  926
# 4                                                 1066
# ..                                                 ...
# 422                                                995
# 423                                               1008
# 424                                               1020
# 425                                                986
# 426                                                986
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 0                                                 1025
# 1                                                 1037
# 2                                                  983
# 3                                                  912
# 4                                                 1051
# ..                                                 ...
# 422                                                976
# 423                                                995
# 424                                                998
# 425                                                958
# 426                                                966
#
#      Index of Economic Resources_score  \
# 0                                 1037
# 1                                  975
# 2                                  972
# 3                                  904
# 4                                 1048
# ..                                 ...
# 422                                988
# 423                               1037
# 424                               1026
# 425                                976
# 426                                961
#
#      Index of Education and Occupation_score   code
# 0                                     1022.0  21001
# 1                                     1088.0  21002
# 2                                     1010.0  21003
# 3                                      946.0  21004
# 4                                     1065.0  21005
# ..                                       ...    ...
# 422                                   1010.0  21476
# 423                                   1003.0  21477
# 424                                   1009.0  21478
# 425                                    952.0  21479
# 426                                    981.0  21480
#
# [427 rows x 185 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=42)

# %%
X_train.head()
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 66                  27                  3                  0
# 132                102                 15                  0
# 223                 91                  7                  0
# 31                  19                  4                  0
# 84                  34                  5                  3
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 66                    0                32                    0
# 132                   0               116                    5
# 223                   0                97                    0
# 31                    0                23                    0
# 84                    0                38                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 66                     0                 0                 32
# 132                    0                 5                121
# 223                    0                 0                101
# 31                     0                 0                 23
# 84                     0                 0                 39
#
#      D_0_4_FPEFT_MPNLF  ...  Total_Lone_Parents_Total_Unemployed  \
# 66                   0  ...                                    0
# 132                  5  ...                                    0
# 223                  3  ...                                    3
# 31                   0  ...                                    0
# 84                   3  ...                                    6
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 66                                      28
# 132                                     24
# 223                                     38
# 31                                       9
# 84                                      37
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 66                                           12
# 132                                          11
# 223                                          45
# 31                                           27
# 84                                           84
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 66                                                   0
# 132                                                  0
# 223                                                  0
# 31                                                   0
# 84                                                   0
#
#      Total_Lone_Parents_Total  \
# 66                         35
# 132                        34
# 223                        90
# 31                         40
# 84                        123
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 66                                                1012
# 132                                               1094
# 223                                               1044
# 31                                                 994
# 84                                                 983
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 66                                                 990
# 132                                               1126
# 223                                               1021
# 31                                                 967
# 84                                                 961
#
#      Index of Economic Resources_score  \
# 66                                 986
# 132                               1013
# 223                               1064
# 31                                1028
# 84                                 991
#
#      Index of Education and Occupation_score   code
# 66                                    1020.0  21069
# 132                                   1168.0  21152
# 223                                    986.0  21240
# 31                                     959.0  21032
# 84                                     952.0  21094
#
# [5 rows x 185 columns]

# %%
X_test
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 419                 27                  5                  0
# 75                  24                  7                  0
# 177                 69                 28                  0
# 30                  16                  5                  0
# 358                458                 55                  3
# ..                 ...                ...                ...
# 376                 98                  8                  4
# 57                  19                  0                  0
# 124                188                 21                  0
# 24                  77                  6                  0
# 17                  31                 19                  0
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 419                   0                30                    0
# 75                    0                30                    0
# 177                   0                95                    3
# 30                    0                25                    0
# 358                   3               514                   11
# ..                  ...               ...                  ...
# 376                   0               107                    0
# 57                    0                23                    0
# 124                   0               211                    7
# 24                    0                85                    3
# 17                    0                46                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 419                    0                 0                 30
# 75                     0                 0                 32
# 177                    3                 4                 94
# 30                     0                 0                 29
# 358                    0                13                525
# ..                   ...               ...                ...
# 376                    0                 3                110
# 57                     0                 0                 23
# 124                    0                 7                216
# 24                     0                 3                 86
# 17                     0                 0                 49
#
#      D_0_4_FPEFT_MPNLF  ...  Total_Lone_Parents_Total_Unemployed  \
# 419                  3  ...                                    0
# 75                   5  ...                                    0
# 177                  6  ...                                    9
# 30                   3  ...                                    0
# 358                 18  ...                                   22
# ..                 ...  ...                                  ...
# 376                  0  ...                                   12
# 57                   6  ...                                    0
# 124                  6  ...                                    4
# 24                   4  ...                                   13
# 17                   0  ...                                   21
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 419                                      4
# 75                                      39
# 177                                     48
# 30                                      11
# 358                                    114
# ..                                     ...
# 376                                     84
# 57                                       9
# 124                                     35
# 24                                      98
# 17                                      70
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 419                                          11
# 75                                           37
# 177                                          94
# 30                                           14
# 358                                         119
# ..                                          ...
# 376                                          83
# 57                                           19
# 124                                         118
# 24                                           63
# 17                                          137
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 419                                                  0
# 75                                                   0
# 177                                                  0
# 30                                                   0
# 358                                                  8
# ..                                                 ...
# 376                                                  0
# 57                                                   0
# 124                                                  7
# 24                                                   0
# 17                                                   0
#
#      Total_Lone_Parents_Total  \
# 419                        19
# 75                         73
# 177                       147
# 30                         32
# 358                       243
# ..                        ...
# 376                       164
# 57                         24
# 124                       156
# 24                        164
# 17                        201
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 419                                               1008
# 75                                                1005
# 177                                                931
# 30                                                1071
# 358                                               1025
# ..                                                 ...
# 376                                               1022
# 57                                                 988
# 124                                               1036
# 24                                                1007
# 17                                                 919
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 419                                                987
# 75                                                 981
# 177                                                949
# 30                                                1063
# 358                                               1024
# ..                                                 ...
# 376                                               1006
# 57                                                 969
# 124                                               1081
# 24                                                 974
# 17                                                 916
#
#      Index of Economic Resources_score  \
# 419                               1038
# 75                                1013
# 177                                898
# 30                                1069
# 358                               1037
# ..                                 ...
# 376                               1009
# 57                                 998
# 124                                941
# 24                                1009
# 17                                 895
#
#      Index of Education and Occupation_score   code
# 419                                    993.0  21473
# 75                                     973.0  21078
# 177                                   1009.0  21199
# 30                                    1080.0  21031
# 358                                   1013.0  21366
# ..                                       ...    ...
# 376                                   1017.0  21380
# 57                                     974.0  21058
# 124                                   1118.0  21144
# 24                                     963.0  21025
# 17                                     954.0  21018
#
# [86 rows x 185 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100) # parameters of the model - change estimators to see if you can get a better outcome

# %% [markdown]
# ### Scaling

# %%
X_train_df = X_train.drop(columns=["code"])
X_test_df = X_test.drop(columns=["code"])

# %%
# Now, we fit our StandardScaler model to our training data. We can apply this StandardScaler model to any future data. Note that we use this fit/transform approach so that we isolate our testing data from the training data that we use to fit our model. Otherwise, we might bias our model to the testing data.
# If working with different units of measurement - allows us to 
# standardised the scaling - reduces the magnitude of numbers while still maintaining the
# truth of the relative distance between our numerical observations
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train_df)
y_scaler = StandardScaler().fit(y_train.to_numpy().reshape(-1, 1))

# when you express different attributes on different scales of magnitude - for the scales
# that result in bigger numbers - your machine learning algorithm may hon in
# on those bigger values because there is more variety within that column - to remove
# that biasing effect of these large numbers we rescale our values - reduce the amount of 
# variety in that column between the largest value and the smallest value.
# reducing the magnitude of the variance within our data.

# %%
# general standard when building a model is to apply some scaling. (mm and kg - rescale mm to m)
# Create versions of our x and y data that have been rescaled
X_train_scaled = X_scaler.transform(X_train_df)
X_test_scaled = X_scaler.transform(X_test_df) # apply same trasformation/scaling to our test data
y_train_scaled = y_scaler.transform(y_train.to_numpy().reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.to_numpy().reshape(-1, 1))

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["Total_Lone_Parents_Total"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["Total_Lone_Parents_Total"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])
# scaled data - same shape just reduced the space that our values fall into - more compact
# rescaling the data - still preserves the underlying truth of the data
# relative positioning of our data remains true

# %%
rf = rf.fit(X_train_scaled, y_train)

# %%
# These are the predictor values
# y_test - values you already know
predict_values = rf.predict(X_test_scaled)
len(predict_values)
# Out:
# 86

# %%
predict_values
# Out:
# array([ 4.64,  9.13, 18.03,  5.15, 38.13, 10.01, 15.73,  7.57,  6.07,
#        15.31, 30.08, 21.35,  4.65,  4.15, 16.92, 12.16, 25.3 ,  3.83,
#         6.82,  3.25, 12.61, 23.37,  8.32, 15.36,  9.34, 11.49, 10.67,
#         5.1 ,  8.01, 22.82,  5.85, 14.78, 10.06,  6.21,  3.62, 23.5 ,
#        10.53,  5.83, 11.59,  5.59, 25.47,  5.25,  9.81, 19.8 ,  7.42,
#        10.59,  5.28, 20.3 ,  6.62,  2.56, 10.61,  5.64, 15.16, 11.75,
#        13.35, 10.71, 35.54,  5.94, 12.01,  9.47,  5.59, 16.96,  4.73,
#         3.89, 33.33,  7.81,  7.97, 15.65, 12.72, 16.54, 27.31,  9.59,
#         9.1 , 12.67, 21.32,  5.64,  7.47, 16.71, 16.48,  8.83, 10.9 ,
#        19.95,  3.32, 19.39, 17.3 , 30.93])

# %%
X_test.head(2)
# Out:
#      D_0_4_FPEFT_MPEFT  D_0_4_FPEFT_MPEPT  D_0_4_FPEFT_MPEAW  \
# 419                 27                  5                  0
# 75                  24                  7                  0
#
#      D_0_4_FPEFT_MPEHNS  D_0_4_FPEFT_MPET  D_0_4_FPEFT_MPULFTW  \
# 419                   0                30                    0
# 75                    0                30                    0
#
#      D_0_4_FPEFT_MPULPTW  D_0_4_FPEFT_MPUT  D_0_4_FPEFT_MPTLF  \
# 419                    0                 0                 30
# 75                     0                 0                 32
#
#      D_0_4_FPEFT_MPNLF  ...  Total_Lone_Parents_Total_Unemployed  \
# 419                  3  ...                                    0
# 75                   5  ...                                    0
#
#      Total_Lone_Parents_Total_Labour_Force  \
# 419                                      4
# 75                                      39
#
#      Total_Lone_Parents_Not_In_The_Labour_Force  \
# 419                                          11
# 75                                           37
#
#      Total_Lone_Parents_Labour_Force_Status_Not_Stated  \
# 419                                                  0
# 75                                                   0
#
#      Total_Lone_Parents_Total  \
# 419                        19
# 75                         73
#
#      Index of Relative Socio-economic Disadvantage_score  \
# 419                                               1008
# 75                                                1005
#
#      Index of Relative Socio-economic Adv and Disadv_score  \
# 419                                                987
# 75                                                 981
#
#      Index of Economic Resources_score  \
# 419                               1038
# 75                                1013
#
#      Index of Education and Occupation_score   code
# 419                                    993.0  21473
# 75                                     973.0  21078
#
# [2 rows x 185 columns]

# %%
y_test = pd.DataFrame(y_test)

# %%
y_test["code"] = X_test["code"]

# %%
y_test["predicted"] = predict_values
y_test.head()
# Out:
#      vulnerable   code  predicted
# 419           3  21473       4.64
# 75            7  21078       9.13
# 177          15  21199      18.03
# 30            8  21031       5.15
# 358          51  21366      38.13

# %%
y_test.shape
# Out:
# (86, 3)

# %%
y_test.to_csv("predictions.csv", index=False)

# %%
# Mean absolute percentage error
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test, predict_values)

# %%
results = sorted(zip(rf.feature_importances_, feature_names), reverse=True)
results

# %%
sum_results = 0
for i in results:
    sum_results += i[0]
    
sum_results
